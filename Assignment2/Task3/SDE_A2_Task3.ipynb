# %% [markdown]
# # **Installing Important Upgrades.**
# ## -> Installing the important libraries

# %%
# !pip install --upgrade google-cloud-vision
# !pip install --upgrade google-cloud
# !pip install --upgrade google-auth

# %% [markdown]
# ## -> After Installing Please **Restart Runtime** for error free computation.

# %%
print(input("Have you Restarted Runtime if not restat now..\n"))
# Out:
# Have you Restarted Runtime if not restat now..
# yes
# yes

# %% [markdown]
# # **Connecting to the Google APi using the key generated in JSON format.**

# %% [markdown]
# ## 1. Importing ALL the important libraries which will be used.
# ### -> 'vision' for the Google cloud API.
# ### -> 'Requests' for getting the images from the site.
# ### -> 'BeautifulSoup' for converting the image in required format.
# ### -> 'GoogleCredentials' for connecting to Google API.
# ### -> 'urllib.request' for accessing and storing the image using url.
# ### -> 'matplotlib.image as mpimg' for accessing and showing the image.
# ### -> 'cv2' for updating the image and boundary rectangle.

# %%
from oauth2client.client import GoogleCredentials
from google.cloud import vision
from bs4 import BeautifulSoup
import urllib.request
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import requests
import os
import cv2
import numpy as np

# %% [markdown]
# ## 2. **Upload** the JSON file that containg the key for connecting to Google APIS (Also provided with other files).

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-380cac43-d731-4c23-b1b6-0100437dad62" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-380cac43-d731-4c23-b1b6-0100437dad62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving task3-343004-711575690c36.json to task3-343004-711575690c36 (1).json
# ...

# %% [markdown]
# ## 3. Set the credential_path to the uploaded JSON file's path (Already set for the Json file provided with the code, just need to upload that same file.)

# %%
credential_path = "task3-343004-711575690c36.json"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = credential_path
print("Service account key is in:",os.environ["GOOGLE_APPLICATION_CREDENTIALS"])
# Out:
# Service account key is in: task3-343004-711575690c36.json

# %% [markdown]
# # **Running the Google API on provided images.**
# ## 1. Get the images - Images were uploaded to the site https://jay0774.github.io/IMAGES/ more images can be uploaded to the same site.

# %%
url = "https://jay0774.github.io/IMAGES/"
html_data = requests.get(url).text
soup = BeautifulSoup(html_data,'html.parser')
image_list = soup.find_all('img')
print("Images uploaded to the sites are:\n")
for i in range(len(image_list)):
  print("Image Number",i+1," has url ",url+image_list[i]['src'])
# Out:
# Images uploaded to the sites are:
#
# Image Number 1  has url  https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img.png
# Image Number 2  has url  https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img_02.jpg
# Image Number 3  has url  https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img_03.jpg
# Image Number 4  has url  https://jay0774.github.io/IMAGES/ASSETS/IMAGES/ex.jpg
# Image Number 5  has url  https://jay0774.github.io/IMAGES/ASSETS/IMAGES/ex1.jpg

# %% [markdown]
# ## 2. Using the API to label the image.

# %%
for i in image_list:
  # creating the client for Image Annotations
  client = vision.ImageAnnotatorClient()
  url_base = url
  image_location = i['src']
  # Getting the source of the image
  image_url = url_base + image_location
  # requesting the image
  r = requests.get(image_url,stream=True)
  img = vision.Image()
  img.source.image_uri = image_url

  # getting the image for detecting the logo and face locally using url
  urllib.request.urlretrieve(image_url,"i.jpg")
  im = mpimg.imread('i.jpg')


  # getting the label detection
  response_client = client.label_detection(image=img)
  # getting the labels given the detector 
  labels = response_client.label_annotations
  # printing the labels description of image 
  if r.status_code == 200:
    print("Label and Conficence for"+" "+image_url,'\n')
    for l in labels:
      print(l.description," has a score of ",l.score*100)
  print('\n')

  # getting the logo detection
  response_client = client.logo_detection(image=img)
  # getting the labels given the detector 
  labels = response_client.logo_annotations
  # showing the logo and the boundary ploygon  
  if r.status_code == 200:
    print("Logo and Conficence for"+" "+image_url,'\n')
    for l in labels:
      print(l.description," has a score of ",l.score*100)
    if l.bounding_poly:
      # getting the statring point of boundary polygon
      x1,y1 = l.bounding_poly.vertices[0].x,l.bounding_poly.vertices[0].y
      # getting the ending point of boundary polygon
      x2,y2 = l.bounding_poly.vertices[2].x,l.bounding_poly.vertices[2].y
      # drawing the boundary polygon using cv2 library
      cv2.rectangle(im, (x1,y1), (x2,y2),(0,255,0), 2)
      # showing the image using the matplotlib bibrary
      imgplot = plt.imshow(im)
      plt.axis('off')
      plt.show()
  print('\n')

  # getting the face detection
  response_client = client.face_detection(image=img)
  # getting the labels given the detector 
  labels = response_client.face_annotations
  # showing the faces and the boundary ploygon   
  if r.status_code == 200:
    print("Face and Conficence for"+" "+image_url,'\n')
    # for each detected face drawing the boundary rectangle.
    for l in labels:
      if l.bounding_poly:
        print("For a new face recognised")
        # getting the statring point of boundary polygon
        x1,y1 = l.bounding_poly.vertices[0].x,l.bounding_poly.vertices[0].y
        # getting the ending point of boundary polygon
        x2,y2 = l.bounding_poly.vertices[2].x,l.bounding_poly.vertices[2].y
        # drawing the boundary polygon using cv2 library
        cv2.rectangle(im, (x1,y1), (x2,y2),(0,255,0), 2)
        # showing the image using the matplotlib bibrary
        imgplot = plt.imshow(im)
        plt.axis('off')
        plt.show()
  print('\n\n')
# Out:
# Label and Conficence for https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img.png
#
# Sky  has a score of  85.71586608886719
# Font  has a score of  79.376620054245
# Electric blue  has a score of  73.51186275482178
# Signage  has a score of  72.58737683296204
# Rectangle  has a score of  71.81704044342041
# Gas  has a score of  70.76938152313232
# Automotive exterior  has a score of  67.44510531425476
# Graphics  has a score of  67.09422469139099
# Brand  has a score of  66.80538058280945
# Sign  has a score of  66.35234355926514
#
#
# Logo and Conficence for https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img.png
#
# Amazon  has a score of  83.73565673828125
# Face and Conficence for https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img.png
#
#
#
#
# Label and Conficence for https://jay0774.github.io/IMAGES/ASSETS/IMAGES/img_02.jpg
#
# Eye  has a score of  93.6380922794342
# Organ  has a score of  90.2567446231842
# Beard  has a score of  87.26038336753845
# ...

# %% [markdown]
# # **For user Defined Input:**

# %%
ch = input("Would you like to import any of your image....y/n:\n")
if ch == 'y':
  f = files.upload()
# Out:
# Would you like to import any of your image....y/n:
# n

# %%
if ch == 'y':
  import io
  i = list(f.keys())[0]
  with io.open(i, "rb") as image_file:
    content = image_file.read()

# %%
if ch == 'y':
  # creating the client for Image Annotations
  client = vision.ImageAnnotatorClient()
  img = vision.Image(content = content)
  im = mpimg.imread(i)


  # getting the label detection
  response_client = client.label_detection(image=img)
  # getting the labels given the detector 
  labels = response_client.label_annotations
  # printing the labels description of image 
  if r.status_code == 200:
    print("Label and Conficence for"+" "+image_url,'\n')
    for l in labels:
      print(l.description," has a score of ",l.score*100)
  print('\n')

  # getting the logo detection
  response_client = client.logo_detection(image=img)
  # getting the labels given the detector 
  labels = response_client.logo_annotations
  # showing the logo and the boundary ploygon  
  if r.status_code == 200:
    print("Logo and Conficence for"+" "+image_url,'\n')
    for l in labels:
      print(l.description," has a score of ",l.score*100)
    if l.bounding_poly:
      # getting the statring point of boundary polygon
      x1,y1 = l.bounding_poly.vertices[0].x,l.bounding_poly.vertices[0].y
      # getting the ending point of boundary polygon
      x2,y2 = l.bounding_poly.vertices[2].x,l.bounding_poly.vertices[2].y
      # drawing the boundary polygon using cv2 library
      cv2.rectangle(im, (x1,y1), (x2,y2),(0,255,0), 2)
      # showing the image using the matplotlib bibrary
      imgplot = plt.imshow(im)
      plt.axis('off')
      plt.show()
  print('\n')

  # getting the face detection
  response_client = client.face_detection(image=img)
  # getting the labels given the detector 
  labels = response_client.face_annotations
  # showing the faces and the boundary ploygon   
  if r.status_code == 200:
    print("Face and Conficence for"+" "+image_url,'\n')
    # for each detected face drawing the boundary rectangle.
    for l in labels:
      if l.bounding_poly:
        print("For a new face recognised")
        # getting the statring point of boundary polygon
        x1,y1 = l.bounding_poly.vertices[0].x,l.bounding_poly.vertices[0].y
        # getting the ending point of boundary polygon
        x2,y2 = l.bounding_poly.vertices[2].x,l.bounding_poly.vertices[2].y
        # drawing the boundary polygon using cv2 library
        cv2.rectangle(im, (x1,y1), (x2,y2),(0,255,0), 2)
        # showing the image using the matplotlib bibrary
        imgplot = plt.imshow(im)
        plt.axis('off')
        plt.show()
  print('\n\n')
